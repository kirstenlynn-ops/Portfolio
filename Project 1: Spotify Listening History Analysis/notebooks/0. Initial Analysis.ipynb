# %% [markdown]
# # Spotify Listening History Initial Analysis
# ---
# - This notebook contains the **raw streaming history data** exported from Spotify for the period **2022-2023** and **2023-2025**.
#
# - The purpose of this notebook is to **import and preview the raw JSON data**, check the essential columns, and save a cleaned CSV version for further analysis.

# %%
#Add libraries
import pandas as pd
import json

# %%
#Load the first JSON file (2022-2023)
with open("Streaming_History_Audio_2022-2023_6.json", "r", encoding="utf-8") as f:
    data_2022_2023 = json.load(f)

#Convert to a DataFrame
df_2022_2023 = pd.DataFrame(data_2022_2023)

#Peek into the first 5 rows
df_2022_2023.head()
# Out:
#                      ts               platform  ms_played conn_country  \
# 0  2022-07-08T14:28:19Z  iOS 15.5 (iPhone13,2)          0           US
# 1  2022-07-08T14:28:20Z  iOS 15.5 (iPhone13,2)        661           US
# 2  2022-07-08T14:28:21Z  iOS 15.5 (iPhone13,2)        725           US
# 3  2022-07-08T14:28:21Z  iOS 15.5 (iPhone13,2)        661           US
# 4  2022-07-08T14:28:22Z  iOS 15.5 (iPhone13,2)        682           US
#
#            ip_addr                         master_metadata_track_name  \
# 0  174.215.249.249                                    Rhyme Or Reason
# 1  174.215.249.249                                           My Fault
# 2  174.215.249.249                               Just the Way You Are
# 3  174.215.249.249                                              Marsh
# 4  174.215.249.249  Can You Feel the Love Tonight - From "The Lion...
#
#   master_metadata_album_artist_name  master_metadata_album_album_name  \
# 0                            Eminem          The Marshall Mathers LP2
# 1                            Eminem                 The Slim Shady LP
# 2                        Bruno Mars              Doo-Wops & Hooligans
# 3                            Eminem  Music To Be Murdered By - Side B
# 4                   Joseph Williams               Disney Summer Songs
#
#                       spotify_track_uri episode_name  ... audiobook_uri  \
# 0  spotify:track:45JxylFwaThjLsRBuzcfoL         None  ...          None
# 1  spotify:track:3CNbDbMHxYHxEgrPGf89yc         None  ...          None
# 2  spotify:track:7BqBn9nzAq8spo5e7cZ0dJ         None  ...          None
# 3  spotify:track:1qFip2ddjfGlKkXDhfBnBr         None  ...          None
# 4  spotify:track:2XQee7HP5QrDwUGHOl6GFf         None  ...          None
#
#   audiobook_chapter_uri audiobook_chapter_title reason_start reason_end  \
# 0                  None                    None      playbtn    endplay
# 1                  None                    None      playbtn    endplay
# 2                  None                    None      playbtn    endplay
# 3                  None                    None      playbtn    endplay
# 4                  None                    None      playbtn    endplay
#
#   shuffle skipped offline  offline_timestamp  incognito_mode
# 0    True   False   False                NaN           False
# 1    True   False   False                NaN           False
# 2    True   False   False                NaN           False
# 3    True   False   False                NaN           False
# 4    True   False   False                NaN           False
#
# [5 rows x 23 columns]

# %% [markdown]
# ### **^Raw data loaded (sensitive columns hidden for privacy)^**

# %%
#Keep only the essential columns
df_2022_2023 = df_2022_2023[[
    "ts",
    "ms_played",
    "master_metadata_track_name",
    "master_metadata_album_artist_name",
    "master_metadata_album_album_name"
]]

#Rename columns for readability
df_2022_2023.rename(columns={
    "ts": "endTime",
    "ms_played": "msPlayed",
    "master_metadata_track_name": "trackName",
    "master_metadata_album_artist_name": "artistName",
    "master_metadata_album_album_name": "albumName"
}, inplace=True)

#Peek at the cleaned DataFrame
df_2022_2023.head()
# Out:
#                 endTime  msPlayed  \
# 0  2022-07-08T14:28:19Z         0
# 1  2022-07-08T14:28:20Z       661
# 2  2022-07-08T14:28:21Z       725
# 3  2022-07-08T14:28:21Z       661
# 4  2022-07-08T14:28:22Z       682
#
#                                            trackName       artistName  \
# 0                                    Rhyme Or Reason           Eminem
# 1                                           My Fault           Eminem
# 2                               Just the Way You Are       Bruno Mars
# 3                                              Marsh           Eminem
# 4  Can You Feel the Love Tonight - From "The Lion...  Joseph Williams
#
#                           albumName
# 0          The Marshall Mathers LP2
# 1                 The Slim Shady LP
# 2              Doo-Wops & Hooligans
# 3  Music To Be Murdered By - Side B
# 4               Disney Summer Songs

# %%
#Save filtered DataFrame as a .csv
df_2022_2023.to_csv("Spotify_2022_2023.csv", index=False)

# %%
#Load the second JSON file (2023-2025)
with open("Streaming_History_Audio_2023-2025_7.json", "r", encoding="utf-8") as f:
    data_2023_2025 = json.load(f)

#Convert to DataFrame
df_2023_2025 = pd.DataFrame(data_2023_2025)

#Peek at the first few rows
df_2023_2025.head()
# Out:
#                      ts platform  ms_played conn_country          ip_addr  \
# 0  2023-05-03T22:30:21Z      ios        768           US   68.229.178.117
# 1  2023-05-03T22:30:25Z      ios       4160           US  174.215.248.238
# 2  2023-05-05T19:54:16Z      ios      89493           US   174.198.68.254
# 3  2023-05-05T20:02:18Z      ios      14826           US   174.198.68.254
# 4  2023-05-05T20:02:19Z      ios        320           US   174.198.68.254
#
#   master_metadata_track_name master_metadata_album_artist_name  \
# 0                    Grenade                        Bruno Mars
# 1              The Lazy Song                        Bruno Mars
# 2                 Nikki Sixx                            Doobie
# 3                Icy Titties                            Doobie
# 4  When the Drugs Don't Work                            Doobie
#
#   master_metadata_album_album_name                     spotify_track_uri  \
# 0             Doo-Wops & Hooligans  spotify:track:2tJulUYLDKOg9XrtVkMgcJ
# 1             Doo-Wops & Hooligans  spotify:track:1ExfPZEiahqhLyajhybFeS
# 2                       Nikki Sixx  spotify:track:4U1j4Di9S3dSqckssFU8kl
# 3                      Icy Titties  spotify:track:4MBxX1P21a0yEZJEHA7zw1
# 4        When the Drugs Don't Work  spotify:track:0i39HdwYbAl5YCEbnBUWeG
#
#   episode_name  ... audiobook_uri audiobook_chapter_uri  \
# 0         None  ...          None                  None
# 1         None  ...          None                  None
# 2         None  ...          None                  None
# 3         None  ...          None                  None
# 4         None  ...          None                  None
#
#   audiobook_chapter_title reason_start                    reason_end shuffle  \
# 0                    None     clickrow                       endplay   False
# 1                    None     clickrow  unexpected-exit-while-paused   False
# 2                    None     clickrow                        fwdbtn   False
# 3                    None       fwdbtn                       endplay   False
# 4                    None     clickrow                       endplay   False
#
#   skipped offline  offline_timestamp  incognito_mode
# 0    True   False       1.683153e+09           False
# 1   False   False       1.683153e+09           False
# 2    True   False       1.683316e+09           False
# 3    True   False       1.683316e+09           False
# 4    True   False       1.683317e+09           False
#
# [5 rows x 23 columns]

# %% [markdown]
# ### **^Raw data loaded (sensitive columns hidden for privacy)^**

# %%
#Keep only the essential columns
df_2023_2025 = df_2023_2025[[
    "ts",
    "ms_played",
    "master_metadata_track_name",
    "master_metadata_album_artist_name",
    "master_metadata_album_album_name"
]]

#Rename columns for readability
df_2023_2025.rename(columns={
    "ts": "endTime",
    "ms_played": "msPlayed",
    "master_metadata_track_name": "trackName",
    "master_metadata_album_artist_name": "artistName",
    "master_metadata_album_album_name": "albumName"
}, inplace=True)

#Peek at the cleaned DataFrame
df_2023_2025.head()
# Out:
#                 endTime  msPlayed                  trackName  artistName  \
# 0  2023-05-03T22:30:21Z       768                    Grenade  Bruno Mars
# 1  2023-05-03T22:30:25Z      4160              The Lazy Song  Bruno Mars
# 2  2023-05-05T19:54:16Z     89493                 Nikki Sixx      Doobie
# 3  2023-05-05T20:02:18Z     14826                Icy Titties      Doobie
# 4  2023-05-05T20:02:19Z       320  When the Drugs Don't Work      Doobie
#
#                    albumName
# 0       Doo-Wops & Hooligans
# 1       Doo-Wops & Hooligans
# 2                 Nikki Sixx
# 3                Icy Titties
# 4  When the Drugs Don't Work

# %%
#Save filtered DataFrame as a .csv
df_2023_2025.to_csv("Spotify_2023_2025.csv", index=False)

# %% [markdown]
# ## Data Preparation Summary | 2022-2023 & 2023-2025 file
# ---
# - Imported Spotify streaming history JSON data for 2022-2023
# - Selected essential features and renamed them for readability
#     - **Timestamp of track playback** (`endTime`)
#     - **Track duration** (`msPlayed`)
#     - **Track Name, artist, and album** (`trackName`),(`artistName`), and (`albumName`)
# - Saved clean CSV for later analysis
# - Repeated on the 2023-2025 JSON file
